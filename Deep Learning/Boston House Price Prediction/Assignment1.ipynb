# %%
import pandas as pd

# %%
df = pd.read_csv("1_boston_housing.csv")

# %%
# Print the Dataset
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
# Column Names and Description :

# crim : per capita crime rate by town
# zn : proportion of residential land zoned for over 25000 sqft
# indus : proportion of non-retail business acres per town
# chas : 1 if tract bounds river, 0 otherwise
# nox : nitric oxide concentration ppm
# rm : average number of rooms per dwelling
# age : proportion of owner houses built before 1940
# dis : weighted distances to 5 Boston employment centres
# rad : accessibility to radial highways
# tax : property tax rate
# ptratio : pupil-teacher ratio in the town
# b : proportion of black people in the town
# lstat : % lower status of population
# medv : median value price of homes

# %%
# Check for Null Values

df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# MEDV       0
# dtype: int64

# %%
# Observe Co-relation between input features and the output variable MEDV
# Positive Co-relation indicates that value of a variable increases as another increases
# Negative Co-relation indicates that value of a variable decreases as another increases and vice-versa

df.corr()['MEDV'].sort_values()
# Out:
# lstat     -0.737663
# ptratio   -0.507787
# indus     -0.483725
# tax       -0.468536
# nox       -0.427321
# crim      -0.388305
# rad       -0.381626
# age       -0.376955
# chas       0.175260
# dis        0.249929
# b          0.333461
# zn         0.360445
# rm         0.695360
# MEDV       1.000000
# Name: MEDV, dtype: float64

# %%
# lstat, ptratio and rm are the features that significantly influence the output variable
# However, the results when only these 3 are considered, vs when all features are considered are not drastically different

# %%
# X = df.loc[:,['lstat', 'ptratio', 'rm']] in case you want to consider only the high impact features

# %%
from sklearn.model_selection import train_test_split

X = df.loc[:,df.columns!='MEDV']
Y = df.loc[:,df.columns=='MEDV']

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.25,random_state=123)

# %%
# MinMax Scaling is a technique used for Normalization,
# So that all the features fall in a specified range, typically from 0 to 1
# The formula is as follows :
# X = (X-Xmin)/(Xmax-Xmin)

# StandardScaling is another Normalization technique,
# It scales the data such that mean of each feature is 0, and the variance is 1
# Since linear regression works well when the featues are normally distributed,
# Robustness to outliers, and preservation of shape of the distribution,
# StandardScaling might be a better normalization technique in our current use case for the given dataset and linear regression

# The formula is as follows :
# Xscaled = (X-u)/σ
# Where u is the mean and σ is the standard deviation

# Hence, here we use StandardScaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# Why do we fit only the X_train and not the X_test?
# We use x_train only for fitting the data,
# To generalize rules that we are going to use when we transform both training and testing data
# Having a peek at X_test to fit defeats the purpose of testing data

# %%
from tensorflow.keras.models import Sequential
# A sequential model, where output of one layer is the input for the next layer

from tensorflow.keras.layers import Dense
# Dense is a type of layer in which reprents a fully connected layer,
# Where each neuron in layer receives input from every neuron in previous layer

model = Sequential()

model.add(Dense(128, input_shape=(13,), activation = 'relu', name = 'layer1'))
# Dense is the type of layer,
# Parameters are number of neurons, input features, activation function and name of the layer
# relu activation function -> rectified linear unit
# f(x) = max(0,x)
# Introduces non linearity in the network, to learn about complex relationships within the data

model.add(Dense(64,activation='relu',name = 'layer2'))
model.add(Dense(1,activation ='linear',name ='output_layer'))

# We have only 1 neuron in output layer,that too with linear activation function for our regression task
# linear activation function > f(x) = x
# Essential so that we obtain only continuous output for our regression

model.compile(optimizer='adam',loss='mse',metrics=['mae'])
# adam optimizer uses adaptive learning ie its learning rate changes during training
# Also utilizes the 'momentum' concept to adjust the gradient descent
# adam optimizer is used to adjust the weights such that the loss metric 'mse' is minimized during training
# The 'mae' metric will be observed at each training epoch

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 128)               1792
#
#  layer2 (Dense)              (None, 64)                8256
#
#  output_layer (Dense)        (None, 1)                 65
#
# =================================================================
# Total params: 10113 (39.50 KB)
# Trainable params: 10113 (39.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# The above provides the model summary,
# Parameters indicate the total weights and biases in each layer
# In layer 1,
# We have 13(inputs)*128(weights)+128 bias for each neuron = 1792 paramters
# For layer 2,
# We have 128(inputs)*64(weights)+64 biases for each neuron = 8256 paramteres
# Recall that it is a fully connected dense layer.

# Trainable parameters are the parameters that will be updated by backpropagation during training
# Non-trainable parameters are the ones that will not be updated.

# Now our model is defined and compiled,we have also given a summary of the model's architecture.
# It is ready to be trained on data

# %%
history = model.fit(X_train,Y_train,epochs=100,validation_split=0.05,verbose=1)

# Epochs represents the number of times the entire training dataset will be passed forward and backward through the neural network
# validation_split is the fraction of data to be used as validation data from the end of training data
# For example if you have 1000 samples
# and validation_split is 0.05, 50 samples from the end will be used for validation and remaining 950 for training.
# Verbose field is to decide whether or not to show the progress bars
# Out:
# Epoch 1/100
# 12/12 [==============================] - 2s 26ms/step - loss: 557.0814 - mae: 21.7176 - val_loss: 547.5168 - val_mae: 21.5072
# Epoch 2/100
# 12/12 [==============================] - 0s 7ms/step - loss: 483.8839 - mae: 20.0518 - val_loss: 466.7935 - val_mae: 19.7544
# Epoch 3/100
# 12/12 [==============================] - 0s 7ms/step - loss: 392.5091 - mae: 17.7842 - val_loss: 363.5780 - val_mae: 17.2254
# Epoch 4/100
# 12/12 [==============================] - 0s 7ms/step - loss: 280.6254 - mae: 14.5586 - val_loss: 241.7935 - val_mae: 13.5877
# Epoch 5/100
# 12/12 [==============================] - 0s 6ms/step - loss: 165.8789 - mae: 10.6565 - val_loss: 135.2951 - val_mae: 9.8866
# Epoch 6/100
# 12/12 [==============================] - 0s 6ms/step - loss: 96.4750 - mae: 7.7466 - val_loss: 75.7305 - val_mae: 7.0228
# Epoch 7/100
# 12/12 [==============================] - 0s 5ms/step - loss: 65.7111 - mae: 6.1595 - val_loss: 49.5472 - val_mae: 5.3737
# Epoch 8/100
# 12/12 [==============================] - 0s 6ms/step - loss: 46.7927 - mae: 5.0985 - val_loss: 35.5195 - val_mae: 4.5862
# Epoch 9/100
# 12/12 [==============================] - 0s 5ms/step - loss: 35.1035 - mae: 4.3752 - val_loss: 26.9940 - val_mae: 4.0055
# Epoch 10/100
# 12/12 [==============================] - 0s 5ms/step - loss: 28.5115 - mae: 3.9085 - val_loss: 21.9712 - val_mae: 3.5330
# Epoch 11/100
100
# 12/12 [==============================] - 0s 7ms/step - loss: 7.5606 - mae: 1.9786 - val_loss: 8.3244 - val_mae: 2.1401
# Epoch 80/100
# 12/12 [==============================] - 0s 8ms/step - loss: 7.4451 - mae: 1.9560 - val_loss: 7.7662 - val_mae: 2.1171
# Epoch 81/100
# 12/12 [==============================] - 0s 6ms/step - loss: 7.3972 - mae: 1.9325 - val_loss: 7.8300 - val_mae: 2.1096
# Epoch 82/100
# 12/12 [==============================] - 0s 7ms/step - loss: 7.5139 - mae: 1.9852 - val_loss: 9.6375 - val_mae: 2.3148
# Epoch 83/100
# 12/12 [==============================] - 0s 7ms/step - loss: 7.2705 - mae: 1.9373 - val_loss: 7.9029 - val_mae: 2.1289
# Epoch 84/100
# 12/12 [==============================] - 0s 9ms/step - loss: 7.2300 - mae: 1.9107 - val_loss: 8.2702 - val_mae: 2.1446
# Epoch 85/100
# 12/12 [==============================] - 0s 7ms/step - loss: 7.2102 - mae: 1.9312 - val_loss: 8.6806 - val_mae: 2.2686
# Epoch 86/100
# 12/12 [==============================] - 0s 9ms/step - loss: 7.2075 - mae: 1.9178 - val_loss: 8.2978 - val_mae: 2.1517
# Epoch 87/100
# 12/12 [==============================] - 0s 11ms/step - loss: 7.0579 - mae: 1.9019 - val_loss: 8.6094 - val_mae: 2.2114
# Epoch 88/100
# 12/12 [==============================] - 0s 9ms/step - loss: 7.0534 - mae: 1.8998 - val_loss: 8.2534 - val_mae: 2.1394
# Epoch 89/100
# 12/12 [==============================] - 0s 7ms/step - loss: 7.0319 - mae: 1.8953 - val_loss: 7.9489 - val_mae: 2.0917
# Epoch 90/100
# 12/12 [==============================] - 0s 7ms/step - loss: 7.0563 - mae: 1.8827 - val_loss: 8.2483 - val_mae: 2.1158
# Epoch 91/100
# 12/12 [==============================] - 0s 8ms/step - loss: 7.0306 - mae: 1.9094 - val_loss: 8.4153 - val_mae: 2.1455
# Epoch 92/100
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9225 - mae: 1.8661 - val_loss: 8.1324 - val_mae: 2.1153
# Epoch 93/100
# 12/12 [==============================] - 0s 10ms/step - loss: 6.8657 - mae: 1.8757 - val_loss: 8.8807 - val_mae: 2.2130
# Epoch 94/100
# 12/12 [==============================] - 0s 10ms/step - loss: 6.8230 - mae: 1.8658 - val_loss: 8.7248 - val_mae: 2.2141
# Epoch 95/100
# 12/12 [==============================] - 0s 8ms/step - loss: 6.8544 - mae: 1.8754 - val_loss: 8.3727 - val_mae: 2.1749
# Epoch 96/100
# 12/12 [==============================] - 0s 5ms/step - loss: 6.8271 - mae: 1.8772 - val_loss: 8.0504 - val_mae: 2.1173
# Epoch 97/100
# 12/12 [==============================] - 0s 6ms/step - loss: 6.8006 - mae: 1.8698 - val_loss: 8.7734 - val_mae: 2.1680
# Epoch 98/100
# 12/12 [==============================] - 0s 5ms/step - loss: 6.8675 - mae: 1.8916 - val_loss: 8.5245 - val_mae: 2.1202
# Epoch 99/100
# 12/12 [==============================] - 0s 5ms/step - loss: 6.7008 - mae: 1.8491 - val_loss: 8.8389 - val_mae: 2.1406
# Epoch 100/100
# 12/12 [==============================] - 0s 5ms/step - loss: 6.6763 - mae: 1.8611 - val_loss: 8.6645 - val_mae: 2.1825

# %%
Y_pred = model.predict(x=X_test)
# Out:
# 4/4 [==============================] - 0s 5ms/step

# %%
for pred, actual in zip(Y_pred,Y_test.values):
  print(f"Predicted : {pred}, Actual : {actual}")
# Out:
# Predicted : [19.31516], Actual : [15.]
# Predicted : [27.941498], Actual : [26.6]
# Predicted : [43.855785], Actual : [45.4]
# Predicted : [19.705301], Actual : [20.8]
# Predicted : [30.564157], Actual : [34.9]
# Predicted : [50.658146], Actual : [21.9]
# Predicted : [26.605011], Actual : [28.7]
# Predicted : [9.482657], Actual : [7.2]
# Predicted : [19.844], Actual : [20.]
# Predicted : [32.787815], Actual : [32.2]
# Predicted : [22.021852], Actual : [24.1]
# Predicted : [20.200796], Actual : [18.5]
# Predicted : [14.211871], Actual : [13.5]
# Predicted : [30.821997], Actual : [27.]
# Predicted : [18.484983], Actual : [23.1]
# Predicted : [19.346554], Actual : [18.9]
# Predicted : [20.044584], Actual : [24.5]
# Predicted : [39.04264], Actual : [43.1]
# Predicted : [16.674026], Actual : [19.8]
# Predicted : [17.136797], Actual : [13.8]
# Predicted : [12.09559], Actual : [15.6]
# Predicted : [32.134342], Actual : [50.]
# Predicted : [35.423912], Actual : [37.2]
# Predicted : [40.928585], Actual : [46.]
# Predicted : [44.115208], Actual : [50.]
# Predicted : [22.511393], Actual : [21.2]
# Predicted : [13.108226], Actual : [14.9]
# Predicted : [19.41096], Actual : [19.6]
# Predicted : [19.42204], Actual : [19.4]
# Predicted : [19.023966], Actual : [18.6]
# Predicted : [25.608736], Actual : [26.5]
# Predicted : [32.522408], Actual : [32.]
# Predicted : [12.932714], Actual : [10.9]
# Predicted : [20.957422], Actual : [20.]
# Predicted : [21.38683], Actual : [21.4]
# Predicted : [34.311134], Actual : [31.]
# Predicted : [25.869852], Actual : [25.]
# Predicted : [12.718236], Actual : [15.4]
# Predicted : [15.7002325], Actual : [13.1]
# Predicted : [43.655766], Actual : [37.6]
# Predicted : [29.362104], Actual : [37.]
# Predicted : [19.395933], Actual : [18.9]
# Predicted : [24.384932], Actual : [27.9]
# Predicted : [46.53358], Actual : [50.]
# Predicted : [23.587133], Actual : [14.4]
# Predicted : [24.938147], Actual : [22.]
# Predicted : [18.070238], Actual : [19.9]
# Predicted : [21.499144], Actual : [21.6]
# Predicted : [16.159485], Actual : [15.6]
# Predicted : [23.78084], Actual : [15.]
# Predicted : [33.93591], Actual : [32.4]
# Predicted : [25.003742], Actual : [29.6]
# Predicted : [17.821276], Actual : [20.4]
# Predicted : [11.505313], Actual : [12.3]
# Predicted : [21.449717], Actual : [19.1]
# Predicted : [14.074473], Actual : [14.9]
# Predicted : [13.246564], Actual : [17.8]
# Predicted : [11.551662], Actual : [8.8]
# Predicted : [34.593082], Actual : [35.4]
# Predicted : [13.85212], Actual : [11.5]
# Predicted : [18.165148], Actual : [19.6]
# Predicted : [21.471983], Actual : [20.6]
# Predicted : [15.580194], Actual : [15.6]
# Predicted : [19.912844], Actual : [19.9]
# Predicted : [21.987661], Actual : [23.3]
# Predicted : [22.207163], Actual : [22.3]
# Predicted : [23.770117], Actual : [24.8]
# Predicted : [23.42367], Actual : [16.1]
# Predicted : [25.721598], Actual : [22.8]
# Predicted : [26.653152], Actual : [30.5]
# Predicted : [20.8563], Actual : [20.4]
# Predicted : [25.046242], Actual : [24.4]
# Predicted : [15.574037], Actual : [16.6]
# Predicted : [26.362896], Actual : [26.2]
# Predicted : [15.311702], Actual : [16.4]
# Predicted : [18.106638], Actual : [20.1]
# Predicted : [11.455594], Actual : [13.9]
# Predicted : [21.428938], Actual : [19.4]
# Predicted : [26.358234], Actual : [22.8]
# Predicted : [13.822358], Actual : [13.8]
# Predicted : [31.933455], Actual : [31.6]
# Predicted : [7.0948677], Actual : [10.5]
# Predicted : [23.38683], Actual : [23.8]
# Predicted : [21.695566], Actual : [22.4]
# Predicted : [19.843187], Actual : [19.3]
# Predicted : [23.891264], Actual : [22.2]
# Predicted : [14.4619665], Actual : [12.6]
# Predicted : [18.700418], Actual : [19.4]
# Predicted : [19.38704], Actual : [22.2]
# Predicted : [28.590584], Actual : [29.8]
# Predicted : [12.439912], Actual : [9.6]
# Predicted : [34.54296], Actual : [34.9]
# Predicted : [22.18936], Actual : [21.4]
# Predicted : [26.586882], Actual : [25.3]
# Predicted : [32.187263], Actual : [32.9]
# Predicted : [32.01828], Actual : [26.6]
# Predicted : [16.107782], Actual : [14.6]
# Predicted : [33.085903], Actual : [31.5]
# Predicted : [28.949923], Actual : [23.3]
# Predicted : [37.814663], Actual : [33.3]
# Predicted : [20.951609], Actual : [17.5]
# Predicted : [14.770041], Actual : [19.1]
# Predicted : [48.877995], Actual : [48.5]
# Predicted : [11.786474], Actual : [17.1]
# Predicted : [23.340725], Actual : [23.1]
# Predicted : [28.328558], Actual : [28.4]
# Predicted : [14.955581], Actual : [18.9]
# Predicted : [11.825841], Actual : [13.]
# Predicted : [20.08063], Actual : [17.2]
# Predicted : [23.125454], Actual : [24.1]
# Predicted : [22.108099], Actual : [18.5]
# Predicted : [24.843832], Actual : [21.8]
# Predicted : [14.620574], Actual : [13.3]
# Predicted : [19.376432], Actual : [23.]
# Predicted : [17.912437], Actual : [14.1]
# Predicted : [20.871614], Actual : [23.9]
# Predicted : [25.37568], Actual : [24.]
# Predicted : [13.339368], Actual : [17.2]
# Predicted : [22.1299], Actual : [21.5]
# Predicted : [18.1828], Actual : [19.1]
# Predicted : [25.79978], Actual : [20.8]
# Predicted : [36.712963], Actual : [36.]
# Predicted : [23.0291], Actual : [20.1]
# Predicted : [8.964108], Actual : [8.7]
# Predicted : [16.406961], Actual : [13.6]
# Predicted : [21.447], Actual : [22.]
# Predicted : [21.474298], Actual : [22.2]

# %%
mse, mae = model.evaluate(X_test,Y_test)

print("Mean Absolute Error in Prediction : ", mae)
print("Mean Squared Error in Prediction : ", mse)
# Out:
# 4/4 [==============================] - 0s 5ms/step - loss: 17.5054 - mae: 2.5661
# Mean Absolute Error in Prediction :  2.566105365753174
# Mean Squared Error in Prediction :  17.505374908447266
